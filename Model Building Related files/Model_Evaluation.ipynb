# %%
import spectral
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Path to the RGB image
rgb_image_path = r"C:\21261A3234\Projects\mini\Datasets\AVIRIS_2021 flight lines\f111116t01p00r19\f111116t01p00r19rdn_c\f111116t01p00r19_sc01_RGB.jpeg"

# Load the RGB image
rgb_image = Image.open(rgb_image_path)

# List of paths to .hdr files
hdr_files = [
    r"C:\21261A3234\Projects\mini\Datasets\AVIRIS_2021 flight lines\f111116t01p00r19\f111116t01p00r19rdn_c\f111116t01p00r19rdn_c_sc01_ort_img.hdr",
    r"C:\21261A3234\Projects\mini\Datasets\AVIRIS_2021 flight lines\f121020t01p00r06\f121020t01p00r06rdn_a\f121020t01p00r06rdn_a_sc01_ort_img.hdr"
]

# Load the hyperspectral images
images = [spectral.open_image(hdr) for hdr in hdr_files]

# Display the images
fig, axs = plt.subplots(1, 2, figsize=(15, 6))

# Display the RGB image
axs[0].imshow(rgb_image)
axs[0].set_title("RGB Image")
axs[0].axis("off")

# Display the first hyperspectral image, selecting an arbitrary band (e.g., band 30)
sample_image = images[0].load()
axs[1].imshow(sample_image[:, :, 30], cmap='gray')
axs[1].set_title("Sample Band 30 of First Hyperspectral Image")
axs[1].axis("off")

plt.show()

# %%
def normalize_image(image):
    # Normalize each band to the range [0, 1]
    normalized_image = (image - image.min()) / (image.max() - image.min())
    return normalized_image

# Normalize the first image as an example
normalized_image = normalize_image(sample_image)

# %%
def image_to_patches(image, patch_size=16):
    patches = []
    h, w, _ = image.shape
    for i in range(0, h - patch_size + 1, patch_size):
        for j in range(0, w - patch_size + 1, patch_size):
            patch = image[i:i + patch_size, j:j + patch_size, :]
            patches.append(patch)
    return np.array(patches)

# Convert the normalized image into patches
patches = image_to_patches(normalized_image)
print("Number of patches:", patches.shape)
# Out:
# Number of patches: (11658, 16, 16, 224)

# %%
import torch
import torch.utils.data as data

class HyperspectralDataset(data.Dataset):
    def __init__(self, patches):
        self.patches = torch.tensor(patches, dtype=torch.float32).permute(0, 3, 1, 2)

    def __len__(self):
        return self.patches.shape[0]

    def __getitem__(self, idx):
        return self.patches[idx], self.patches[idx]

# Initialize dataset and dataloader
dataset = HyperspectralDataset(patches)
dataloader = data.DataLoader(dataset, batch_size=16, shuffle=True)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class ConvAutoencoder(nn.Module):
    def __init__(self):
        super(ConvAutoencoder, self).__init__()
        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(224, 128, 3, stride=2, padding=1),  # Input channels = bands
            nn.ReLU(),
            nn.Conv2d(128, 64, 3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 32, 3, stride=2, padding=1),
            nn.ReLU()
        )
        
        # Decoder
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(32, 64, 3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 128, 3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 224, 3, stride=2, padding=1, output_padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# Initialize model, loss, and optimizer
model = ConvAutoencoder()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Initialize a list to store loss history
loss_history = []

# Training loop
epochs = 50
for epoch in range(epochs):
    for data in dataloader:
        inputs, _ = data
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, inputs)
        loss.backward()
        optimizer.step()
    loss_history.append(loss.item())  # Save the loss for this epoch
    print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item()}')
# Out:
# Epoch 1/50, Loss: 0.001063224975951016
# Epoch 2/50, Loss: 0.0006805500597693026
# Epoch 3/50, Loss: 0.000819600943941623
# Epoch 4/50, Loss: 0.00031817768467590213
# Epoch 5/50, Loss: 0.0007971989107318223
# Epoch 6/50, Loss: 0.000871119205839932
# Epoch 7/50, Loss: 0.0005189867224544287
# Epoch 8/50, Loss: 0.0008103291620500386
# Epoch 9/50, Loss: 0.0011298662284389138
# Epoch 10/50, Loss: 0.0013288924237713218
# Epoch 11/50, Loss: 0.0009801615960896015
# Epoch 12/50, Loss: 0.0007868217071518302
# Epoch 13/50, Loss: 0.0005733203724958003
# Epoch 14/50, Loss: 0.0002522444410715252
# Epoch 15/50, Loss: 0.0008178051793947816
# Epoch 16/50, Loss: 0.0008656156132929027
# Epoch 17/50, Loss: 0.0009132804698310792
# Epoch 18/50, Loss: 0.0011707523372024298
# Epoch 19/50, Loss: 0.0007394706481136382
# Epoch 20/50, Loss: 0.0007022691424936056
# Epoch 21/50, Loss: 0.0008078770479187369
# Epoch 22/50, Loss: 0.00046095644938759506
# Epoch 23/50, Loss: 0.0007181639084592462
# Epoch 24/50, Loss: 0.0007493364391848445
# Epoch 25/50, Loss: 0.0008475761860609055
# Epoch 26/50, Loss: 0.0014040542300790548
# Epoch 27/50, Loss: 0.00034340537968091667
# Epoch 28/50, Loss: 0.0009405473247170448
# Epoch 29/50, Loss: 0.0008040919783525169
# Epoch 30/50, Loss: 0.0006875952240079641
# Epoch 31/50, Loss: 0.0013543062377721071
# Epoch 32/50, Loss: 0.0009449183708056808
# Epoch 33/50, Loss: 0.0008549465565010905
# Epoch 34/50, Loss: 0.0006702079554088414
# Epoch 35/50, Loss: 0.0003350608458276838
# Epoch 36/50, Loss: 0.0006559472531080246
# Epoch 37/50, Loss: 0.0008930366020649672
# Epoch 38/50, Loss: 0.0006604755762964487
# Epoch 39/50, Loss: 0.0010181228863075376
# Epoch 40/50, Loss: 0.0008298763423226774
# Epoch 41/50, Loss: 0.0011563157895579934
# Epoch 42/50, Loss: 0.0008742689387872815
# Epoch 43/50, Loss: 0.0009418455883860588
# Epoch 44/50, Loss: 0.0006182834040373564
# Epoch 45/50, Loss: 0.0006601476343348622
# Epoch 46/50, Loss: 0.0006086845532990992
# Epoch 47/50, Loss: 0.0007370124803856015
# Epoch 48/50, Loss: 0.0007402288028970361
# Epoch 49/50, Loss: 0.0010259588016197085
# Epoch 50/50, Loss: 0.000563720241189003
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 29
#      26         pickle.dump(loss_history, f)
#      28 # Call the save function at the end of your training loop
# ---> 29 save_training_state(model, optimizer, loss_history)
#
# Cell In[18], line 26, in save_training_state(model, optimizer, loss_history)
#      24 # Save the loss history
#      25 with open('loss_history.pkl', 'wb') as f:
# ---> 26     pickle.dump(loss_history, f)
#
# NameError: name 'pickle' is not defined

# %%
import torch
import pickle

# Define a function to save model and other variables
def save_training_state(model, optimizer, loss_history):
    # Save the model state
    torch.save(model.state_dict(), 'model_weights.pth')
    
    # Save the optimizer state
    torch.save(optimizer.state_dict(), 'optimizer_state.pth')
    
    # Save the loss history
    with open('loss_history.pkl', 'wb') as f:
        pickle.dump(loss_history, f)

# Call the save function at the end of your training loop
save_training_state(model, optimizer, loss_history)

# %%
import torch
import pickle
import warnings

# Define a function to load the model, optimizer, and loss history
def load_training_state(model, optimizer):
    # Load the model state with `weights_only=True`
    model.load_state_dict(torch.load('model_weights.pth', weights_only=True))
    
    # Suppress the specific warning temporarily for loading optimizer state
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=FutureWarning)
        optimizer.load_state_dict(torch.load('optimizer_state.pth'))
    
    # Load the loss history
    with open('loss_history.pkl', 'rb') as f:
        loss_history = pickle.load(f)
    
    return model, optimizer, loss_history

# Example usage:
model, optimizer, loss_history = load_training_state(model, optimizer)

# %%
from skimage.metrics import structural_similarity as ssim
import torch
import numpy as np

def evaluate_autoencoder(dataloader, model):
    model.eval()  # Set model to evaluation mode
    mse_losses = []
    ssim_scores = []

    with torch.no_grad():
        for data in dataloader:
            inputs, _ = data
            outputs = model(inputs)

            # Calculate MSE per batch using PyTorch
            mse_loss = ((outputs - inputs) ** 2).mean().item()
            mse_losses.append(mse_loss)

            # Calculate SSIM per patch
            for i in range(inputs.size(0)):
                original = inputs[i].cpu().numpy().transpose(1, 2, 0)
                reconstructed = outputs[i].cpu().numpy().transpose(1, 2, 0)
                ssim_score = ssim(original, reconstructed, data_range=1.0, multichannel=True)
                ssim_scores.append(ssim_score)

    # Calculate average MSE and SSIM for final evaluation
    avg_mse = np.mean(mse_losses)
    avg_ssim = np.mean(ssim_scores)
    print(f'Evaluation MSE: {avg_mse}')
    print(f'Evaluation SSIM: {avg_ssim}')
    return avg_mse, avg_ssim

# Run evaluation on the test set
avg_mse, avg_ssim = evaluate_autoencoder(dataloader, model)
# Out:
# Evaluation MSE: 0.0003102352647844604
# Evaluation SSIM: 0.707059023126457

# %%
import json

# Function to save evaluation metrics to a JSON file
def save_evalmetrics_to_json(avg_mse, avg_ssim, file_path="evalmetrics.json"):
    metrics = {
        "avg_mse": avg_mse,
        "avg_ssim": avg_ssim
    }
    with open(file_path, "w") as f:
        json.dump(metrics, f)

# Save the metrics
save_evalmetrics_to_json(avg_mse, avg_ssim)

# %%
def calculate_anomalies(dataloader, model, threshold=0.01):
    model.eval()
    anomaly_scores = []

    with torch.no_grad():
        for inputs, _ in dataloader:
            outputs = model(inputs)

            # Ensure outputs and inputs have matching shapes for MSE calculation
            if outputs.shape != inputs.shape:
                outputs = torch.nn.functional.interpolate(outputs, size=inputs.shape[2:], mode='bilinear', align_corners=False)

            # Calculate the per-patch loss
            losses = ((outputs - inputs) ** 2).mean(dim=[1, 2, 3])  # Mean squared error per patch
            anomaly_scores.extend(losses.cpu().numpy())  # Collect scores for each patch

    # Normalize the anomaly scores to range [0, 1]
    anomaly_scores = np.array(anomaly_scores)
    anomaly_scores = (anomaly_scores - anomaly_scores.min()) / (anomaly_scores.max() - anomaly_scores.min())
    
    # Return a boolean array where True indicates an anomaly
    return anomaly_scores > threshold

# Calculate anomalies for patches
anomalies = calculate_anomalies(dataloader, model)

def visualize_anomalies_with_original(image, anomalies, patch_size=16):
    h, w, _ = image.shape
    anomaly_image = np.zeros((h, w))

    patch_idx = 0
    for i in range(0, h - patch_size + 1, patch_size):
        for j in range(0, w - patch_size + 1, patch_size):
            if anomalies[patch_idx]:
                anomaly_image[i:i + patch_size, j:j + patch_size] = 1  # Mark anomaly
            patch_idx += 1

    plt.figure(figsize=(12, 6))

    # Show original image
    plt.subplot(1, 2, 1)
    plt.imshow(image[:, :, 30], cmap='gray')
    plt.title("Original Image - Band 30")

    # Show anomaly map
    plt.subplot(1, 2, 2)
    plt.imshow(anomaly_image, cmap='hot', interpolation='nearest')
    plt.title("Detected Anomalies")

    plt.show()

# Visualize the anomalies with the original image
visualize_anomalies_with_original(sample_image, anomalies)

# %%
def extract_spectral_signatures(anomalies, image, patch_size=16):
    """
    Extracts the spectral signatures of patches identified as anomalies.

    Parameters:
    - anomalies: Boolean array where True indicates an anomaly patch.
    - image: The original hyperspectral image (normalized).
    - patch_size: Size of each patch (default is 16).

    Returns:
    - spectral_signatures: A list containing the spectral signature of each anomaly.
    """
    h, w, bands = image.shape
    spectral_signatures = []
    patch_idx = 0

    for i in range(0, h - patch_size + 1, patch_size):
        for j in range(0, w - patch_size + 1, patch_size):
            if anomalies[patch_idx]:
                # Extract the patch and calculate the mean spectral signature
                patch = image[i:i + patch_size, j:j + patch_size, :]
                mean_spectral_signature = patch.mean(axis=(0, 1))  # Average over spatial dimensions
                spectral_signatures.append(mean_spectral_signature)
            patch_idx += 1

    return spectral_signatures

# Extract spectral signatures for anomalies
spectral_signatures = extract_spectral_signatures(anomalies, normalized_image)

def plot_spectral_signatures(spectral_signatures):
    plt.figure(figsize=(10, 6))
    for signature in spectral_signatures:
        plt.plot(signature)
    plt.xlabel("Wavelength Bands")
    plt.ylabel("Reflectance")
    plt.title("Spectral Signatures of Detected Anomalies")
    plt.show()

# Plot the spectral signatures of anomalies
plot_spectral_signatures(spectral_signatures)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# Specify the path to your spectrum file
file_path = r"C:\21261A3234\Projects\mini\Datasets\ecospeclib_1730360875648\ecospeclib-all\mineral.phosphate.none.medium.vswir.p-3a.jpl.perkin.spectrum.txt"

# Define the number of header lines to skip (assuming the metadata ends after 22 lines)
header_lines = 22

# Load data, skipping header lines and assuming the file is tab-separated
data = pd.read_csv(file_path, sep='\t', skiprows=header_lines, header=None, names=['Wavelength', 'Reflectance'])

# Save the library signature to a variable
library_signature = data

# Save the library signature to a .pickle file for future use
with open('library_signature.pkl', 'wb') as f:
    pickle.dump(library_signature, f)

# Plotting reflectance vs. wavelength
plt.figure(figsize=(10, 6))
plt.plot(data['Wavelength'], data['Reflectance'], label='Spectral Signature')
plt.xlabel('Wavelength')
plt.ylabel('Reflectance')
plt.title('Distilled Water Spectral Signature Plot')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import pickle

# Load the saved library signature with wavelengths and reflectance values
with open('library_signature.pkl', 'rb') as f:
    library_signature_df = pickle.load(f)

# Extract only the Reflectance values and convert to a 1D array
library_signature = library_signature_df['Reflectance'].values

# Assuming `spectral_signatures` is a list of 1D numpy arrays where each array represents a signature
# Ensure all signatures are of the same length
resampled_length = len(library_signature)
spectral_signatures = [np.interp(np.linspace(0, 1, resampled_length), 
                                 np.linspace(0, 1, len(signature)), 
                                 signature) for signature in spectral_signatures]

def spectral_angle_mapper(vector1, vector2):
    """
    Calculate the Spectral Angle Mapper (SAM) between two spectral signatures.

    Parameters:
    - vector1: First spectral signature.
    - vector2: Second spectral signature (should be resampled if needed).

    Returns:
    - angle: SAM angle in radians or NaN if unable to calculate.
    """
    dot_product = np.dot(vector1, vector2)
    norm1 = np.linalg.norm(vector1)
    norm2 = np.linalg.norm(vector2)

    # Check if either vector has zero norm
    if norm1 == 0 or norm2 == 0:
        return np.nan  # Return NaN if the SAM cannot be calculated

    # Calculate cosine similarity
    cosine_similarity = dot_product / (norm1 * norm2)
    
    # Ensure cosine_similarity is within the valid range for arccos
    cosine_similarity = np.clip(cosine_similarity, -1, 1)
    
    # Calculate and return the SAM angle
    angle = np.arccos(cosine_similarity)
    return angle

# Calculate SAM values between each anomaly and the library signature
sams = [spectral_angle_mapper(signature, library_signature) for signature in spectral_signatures]

# Output SAM values
for idx, sam in enumerate(sams):
    print(f"SAM between anomaly {idx + 1} and library signature: {sam} radians")
# Out:
# SAM between anomaly 1 and library signature: nan radians
# SAM between anomaly 2 and library signature: nan radians
# SAM between anomaly 3 and library signature: nan radians
# SAM between anomaly 4 and library signature: nan radians
# SAM between anomaly 5 and library signature: nan radians
# SAM between anomaly 6 and library signature: nan radians
# SAM between anomaly 7 and library signature: nan radians
# SAM between anomaly 8 and library signature: nan radians
# SAM between anomaly 9 and library signature: nan radians
# SAM between anomaly 10 and library signature: nan radians
# SAM between anomaly 11 and library signature: nan radians
# SAM between anomaly 12 and library signature: nan radians
# SAM between anomaly 13 and library signature: nan radians
# SAM between anomaly 14 and library signature: 0.9468763870657438 radians
# SAM between anomaly 15 and library signature: 0.968728349306899 radians
# SAM between anomaly 16 and library signature: 1.0005245938382608 radians
# SAM between anomaly 17 and library signature: 0.9547763586387339 radians
# SAM between anomaly 18 and library signature: 0.9675642902584543 radians
# SAM between anomaly 19 and library signature: 0.9637911871686741 radians
# SAM between anomaly 20 and library signature: 0.9852558634096344 radians
# SAM between anomaly 21 and library signature: 0.9815264010260578 radians
# SAM between anomaly 22 and library signature: 0.9420624501566045 radians
# SAM between anomaly 23 and library signature: 0.9607862737209248 radians
# SAM between anomaly 24 and library signature: 0.9074945357150365 radians
# SAM between anomaly 25 and library signature: 0.9206819719153502 radians
# SAM between anomaly 26 and library signature: 0.9285004879916046 radians
# SAM between anomaly 27 and library signature: 0.9713285935970386 radians
# SAM between anomaly 28 and library signature: 0.9851444096581694 radians
# SAM between anomaly 29 and library signature: 0.9332947952848795 radians
# SAM between anomaly 30 and library signature: nan radians
# SAM between anomaly 31 and library signature: nan radians
# SAM between anomaly 32 and library signature: nan radians
# SAM between anomaly 33 and library signature: nan radians
# SAM between anomaly 34 and library signature: nan radians
# SAM between anomaly 35 and library signature: nan radians
# SAM between anomaly 36 and library signature: nan radians
# SAM between anomaly 37 and library signature: nan radians
# SAM between anomaly 38 and library signature: nan radians
# SAM between anomaly 39 and library signature: nan radians
# SAM between anomaly 40 and library signature: nan radians
# SAM between anomaly 41 and library signature: nan radians
# SAM between anomaly 42 and library signature: nan radians
# SAM between anomaly 43 and library signature: nan radians
# SAM between anomaly 44 and library signature: nan radians
# SAM between anomaly 45 and library signature: nan radians
# SAM between anomaly 46 and library signature: nan radians
# SAM between anomaly 47 and library signature: nan radians
# SAM between anomaly 48 and library signature: 0.9410356373558912 radians
# SAM between anomaly 49 and library signature: 0.9677771990908748 radians
# SAM between anomaly 50 and library signature: 0.94632349408871 radians
# SAM between anomaly 51 and library signature: 0.9592300537749554 radians
# SAM between anomaly 52 and library signature: 0.9514354753400546 radians
# SAM between anomaly 53 and library signature: 0.9698184376085435 radians
# SAM between anomaly 54 and library signature: 0.9692074988520339 radians
# SAM between anomaly 55 and library signature: 0.958335889821428 radians
# SAM between anomaly 56 and library signature: 0.9854698884743498 radians
# SAM between anomaly 57 and library signature: 0.9926730185133779 radians
# SAM between anomaly 58 and library signature: 0.9768680987874752 radians
# SAM between anomaly 59 and library signature: 0.9654161375040873 radians
# SAM between anomaly 60 and library signature: 0.9129423818700965 radians
# SAM between anomaly 61 and library signature: 0.9549652049693258 radians
# SAM between anomaly 62 and library signature: 0.9365786831892208 radians
# SAM between anomaly 63 and library signature: 0.9519455695868496 radians
# SAM between anomaly 64 and library signature: 0.9234870237074092 radians
# SAM between anomaly 65 and library signature: 0.938740870488866 radians
# SAM between anomaly 66 and library signature: 0.9543733534815516 radians
# SAM between anomaly 67 and library signature: 0.931719015204786 radians
# SAM between anomaly 68 and library signature: 0.8548517901510303 radians
# SAM between anomaly 69 and library signature: 0.8307702747927751 radians
# SAM between anomaly 70 and library signature: 0.8595190495340528 radians
# SAM between anomaly 71 and library signature: 0.8504707025386812 radians
# SAM between anomaly 72 and library signature: 0.82448838939065 radians
# SAM between anomaly 73 and library signature: 0.9015380033847527 radians
# SAM between anomaly 74 and library signature: 0.9139949153469433 radians
# SAM between anomaly 75 and library signature: nan radians
# SAM between anomaly 76 and library signature: nan radians
# SAM between anomaly 77 and library signature: nan radians
# SAM between anomaly 78 and library signature: nan radians
# SAM between anomaly 79 and library signature: nan radians
# SAM between anomaly 80 and library signature: nan radians
# SAM between anomaly 81 and library signature: nan radians
# SAM between anomaly 82 and library signature: nan radians
# SAM between anomaly 83 and library signature: nan radians
# SAM between anomaly 84 and library signature: 0.9430850705826395 radians
# SAM between anomaly 85 and library signature: 0.9293084756870522 radians
# SAM between anomaly 86 and library signature: 0.9337760992826976 radians
# SAM between anomaly 87 and library signature: 0.9224094212951822 radians
# SAM between anomaly 88 and library signature: 0.9160943530298623 radians
# SAM between anomaly 89 and library signature: 0.9262775856303138 radians
# SAM between anomaly 90 and library signature: 0.9385659733681098 radians
# SAM between anomaly 91 and library signature: 0.9469529873807458 radians
# SAM between anomaly 92 and library signature: 0.9497444379695293 radians
# SAM between anomaly 93 and library signature: 0.9661401824691936 radians
# SAM between anomaly 94 and library signature: 0.9732158128171804 radians
# SAM between anomaly 95 and library signature: 0.96177225289965 radians
# SAM between anomaly 96 and library signature: 0.9695362573933337 radians
# SAM between anomaly 97 and library signature: 0.9723192317359328 radians
# SAM between anomaly 98 and library signature: 0.9453403117457282 radians
# SAM between anomaly 99 and library signature: 0.9698090415656192 radians
# SAM between anomaly 100 and library signature: 0.9614376737896712 radians
# SAM between anomaly 101 and library signature: 0.9571635494567065 radians
# SAM between anomaly 102 and library signature: 0.9634584383942603 radians
# SAM between anomaly 103 and library signature: 0.9351551394078773 radians
# SAM between anomaly 104 and library signature: 0.9381397869587146 radians
# SAM between anomaly 105 and library signature: 0.9236458990467549 radians
# SAM between anomaly 106 and library signature: 0.954844677983569 radians
# SAM between anomaly 107 and library signature: 0.9645659079631578 radians
# SAM between anomaly 108 and library signature: 0.9605619995859852 radians
# SAM between anomaly 109 and library signature: 0.9061434693395518 radians
# SAM between anomaly 110 and library signature: 0.9219311239927392 radians
# SAM between anomaly 111 and library signature: 0.9219019306991765 radians
# SAM between anomaly 112 and library signature: 0.852142696851806 radians
# SAM between anomaly 113 and library signature: 0.920224474098433 radians
# SAM between anomaly 114 and library signature: 0.8891917762554582 radians
# SAM between anomaly 115 and library signature: 0.8901619500078494 radians
# SAM between anomaly 116 and library signature: 0.925084877421029 radians
# SAM between anomaly 117 and library signature: 0.9603964157035715 radians
# SAM between anomaly 118 and library signature: 0.9233991595299863 radians
# SAM between anomaly 119 and library signature: 0.9490710811671028 radians
# SAM between anomaly 120 and library signature: 0.9508097000942164 radians
# SAM between anomaly 121 and library signature: 0.9179820233645798 radians
# SAM between anomaly 122 and library signature: 0.8294478287792787 radians
# SAM between anomaly 123 and library signature: 0.8408056207759521 radians
# SAM between anomaly 124 and library signature: 0.8602573307456614 radians
# SAM between anomaly 125 and library signature: 0.8664085777090247 radians
# SAM between anomaly 126 and library signature: 0.8675272213399163 radians
# SAM between anomaly 127 and library signature: 0.9559995782860502 radians
# SAM between anomaly 128 and library signature: 0.9246974037338502 radians
# SAM between anomaly 129 and library signature: 0.9048158316453849 radians
# SAM between anomaly 130 and library signature: 0.9242397464160597 radians
# SAM between anomaly 131 and library signature: 0.9146425764768579 radians
# SAM between anomaly 132 and library signature: 0.9244409568553277 radians
# SAM between anomaly 133 and library signature: 0.9329333409675248 radians
# SAM between anomaly 134 and library signature: 0.9456508586026514 radians
# SAM between anomaly 135 and library signature: 0.9556815365551278 radians
# SAM between anomaly 136 and library signature: 0.9460111498661767 radians
# SAM between anomaly 137 and library signature: 0.9572542821072749 radians
# SAM between anomaly 138 and library signature: 0.9226478605144874 radians
# SAM between anomaly 139 and library signature: 0.9173362365433477 radians
# SAM between anomaly 140 and library signature: 0.9317391624386633 radians
# SAM between anomaly 141 and library signature: 0.9110995223604583 radians
# SAM between anomaly 142 and library signature: 0.9139141665971475 radians
# SAM between anomaly 143 and library signature: 0.9240819753178857 radians
# SAM between anomaly 144 and library signature: 0.9183772130089833 radians
# SAM between anomaly 145 and library signature: 0.9245712126991354 radians
# SAM between anomaly 146 and library signature: 0.9240645937998077 radians
# SAM between anomaly 147 and library signature: 0.9334218161853488 radians
# SAM between anomaly 148 and library signature: 0.958316313462931 radians
# SAM between anomaly 149 and library signature: 0.971731944394037 radians
# SAM between anomaly 150 and library signature: 0.9864963380302598 radians
# SAM between anomaly 151 and library signature: 0.9988959382660738 radians
# SAM between anomaly 152 and library signature: 0.9689052796868273 radians
# SAM between anomaly 153 and library signature: 0.9593614128613441 radians
# SAM between anomaly 154 and library signature: 0.9414925165013888 radians
# SAM between anomaly 155 and library signature: 0.9453260217941393 radians
# SAM between anomaly 156 and library signature: 0.9572552460320927 radians
# SAM between anomaly 157 and library signature: 0.9500147898520824 radians
# SAM between anomaly 158 and library signature: 0.8256831735336276 radians
# SAM between anomaly 159 and library signature: 0.8449823709718264 radians
# SAM between anomaly 160 and library signature: 0.8719105193662661 radians
# SAM between anomaly 161 and library signature: 0.9413529454529669 radians
# SAM between anomaly 162 and library signature: 0.9728298745497125 radians
# SAM between anomaly 163 and library signature: 0.9511075332036274 radians
# SAM between anomaly 164 and library signature: 0.9629724251344524 radians
# SAM between anomaly 165 and library signature: 0.9685230723832301 radians
# SAM between anomaly 166 and library signature: 0.9509031461763089 radians
# SAM between anomaly 167 and library signature: 0.9607994307924549 radians
# SAM between anomaly 168 and library signature: 0.940810392464603 radians
# SAM between anomaly 169 and library signature: 0.9875308721669878 radians
# SAM between anomaly 170 and library signature: 0.9229435302240511 radians
# SAM between anomaly 171 and library signature: 0.9372328939276551 radians
# SAM between anomaly 172 and library signature: 0.9479388429921641 radians
# SAM between anomaly 173 and library signature: 0.9691490991396173 radians
# SAM between anomaly 174 and library signature: 0.9245050002914292 radians
# SAM between anomaly 175 and library signature: 0.9048351431478265 radians
# SAM between anomaly 176 and library signature: 0.8945292666812102 radians
# SAM between anomaly 177 and library signature: 0.8622099035660341 radians
# SAM between anomaly 178 and library signature: 0.8570934792655305 radians
# SAM between anomaly 179 and library signature: 0.8516847009639487 radians
# SAM between anomaly 180 and library signature: 0.8858333230138146 radians
# SAM between anomaly 181 and library signature: 0.9059133136211498 radians
# SAM between anomaly 182 and library signature: 0.9239268917000004 radians
# SAM between anomaly 183 and library signature: 0.9582707428080642 radians
# SAM between anomaly 184 and library signature: 0.9710650055740231 radians
# SAM between anomaly 185 and library signature: 0.9981318009632291 radians
# SAM between anomaly 186 and library signature: 1.006519101097367 radians
# SAM between anomaly 187 and library signature: 0.9274064072099354 radians
# SAM between anomaly 188 and library signature: 0.9195813200817812 radians
# SAM between anomaly 189 and library signature: 0.9187623024789643 radians
# SAM between anomaly 190 and library signature: 0.9206941454826141 radians
# SAM between anomaly 191 and library signature: 0.9085168366989673 radians
# SAM between anomaly 192 and library signature: 0.913385796729892 radians
# SAM between anomaly 193 and library signature: 0.9442669365698882 radians
# SAM between anomaly 194 and library signature: 0.9407895832761862 radians
# SAM between anomaly 195 and library signature: 0.9823039950055306 radians
# SAM between anomaly 196 and library signature: 0.9691700063295217 radians
# SAM between anomaly 197 and library signature: 0.9406839852057648 radians
# SAM between anomaly 198 and library signature: 0.9886096844996604 radians
# SAM between anomaly 199 and library signature: 1.009214102462527 radians
# SAM between anomaly 200 and library signature: 0.9224270164293707 radians
# SAM between anomaly 201 and library signature: 0.9437383640950727 radians
# SAM between anomaly 202 and library signature: 0.9608647790093471 radians
# SAM between anomaly 203 and library signature: 0.9825855456020022 radians
# SAM between anomaly 204 and library signature: 0.8572319565733626 radians
# SAM between anomaly 205 and library signature: 0.8127037869435056 radians
# SAM between anomaly 206 and library signature: 0.9771803663349441 radians
# SAM between anomaly 207 and library signature: 0.9818414702156987 radians
# SAM between anomaly 208 and library signature: 0.9526859135879986 radians
# SAM between anomaly 209 and library signature: 0.963920115543556 radians
# SAM between anomaly 210 and library signature: 0.9544552642125201 radians
# SAM between anomaly 211 and library signature: 0.9473533369454243 radians
# SAM between anomaly 212 and library signature: 0.9543193088949722 radians
# SAM between anomaly 213 and library signature: 0.9431455247431827 radians
# SAM between anomaly 214 and library signature: 0.929767503594793 radians
# SAM between anomaly 215 and library signature: 0.9469855756549067 radians
# SAM between anomaly 216 and library signature: 0.9254660753346675 radians
# SAM between anomaly 217 and library signature: 0.9200395846956333 radians
# SAM between anomaly 218 and library signature: 0.9005632386918149 radians
# SAM between anomaly 219 and library signature: 0.8924094256892539 radians
# SAM between anomaly 220 and library signature: 0.900909341503329 radians
# SAM between anomaly 221 and library signature: 0.9084424107775494 radians
# SAM between anomaly 222 and library signature: 0.8367715005848823 radians
# SAM between anomaly 223 and library signature: 0.8921875701829992 radians
# SAM between anomaly 224 and library signature: 0.9028181099185064 radians
# SAM between anomaly 225 and library signature: 0.9250304921706379 radians
# SAM between anomaly 226 and library signature: nan radians
# SAM between anomaly 227 and library signature: nan radians
# SAM between anomaly 228 and library signature: nan radians
# SAM between anomaly 229 and library signature: 0.9410518265969735 radians
# SAM between anomaly 230 and library signature: 0.9708767288493366 radians
# SAM between anomaly 231 and library signature: 0.9803971655809726 radians
# SAM between anomaly 232 and library signature: 0.9685544507002979 radians
# SAM between anomaly 233 and library signature: 0.9166642939786066 radians
# SAM between anomaly 234 and library signature: 0.9598071396371779 radians
# SAM between anomaly 235 and library signature: 0.9617161376686423 radians
# SAM between anomaly 236 and library signature: 0.9467676963364748 radians
# SAM between anomaly 237 and library signature: 0.9370519485234451 radians
# SAM between anomaly 238 and library signature: 0.9215342260528808 radians
# SAM between anomaly 239 and library signature: 0.9200894548904388 radians
# SAM between anomaly 240 and library signature: 0.9379495297496868 radians
# SAM between anomaly 241 and library signature: 0.9666212984464337 radians
# SAM between anomaly 242 and library signature: 0.9627908090554259 radians
# SAM between anomaly 243 and library signature: 0.9673089235725749 radians
# SAM between anomaly 244 and library signature: 0.9446197212206672 radians
# SAM between anomaly 245 and library signature: 0.9773879763074881 radians
# SAM between anomaly 246 and library signature: 0.9584003717030493 radians
# SAM between anomaly 247 and library signature: 0.9046497254719851 radians
# SAM between anomaly 248 and library signature: 0.9623389912368601 radians
# SAM between anomaly 249 and library signature: 0.983604040705073 radians
# SAM between anomaly 250 and library signature: 0.9813041000520292 radians
# SAM between anomaly 251 and library signature: 0.9691020444223595 radians
# SAM between anomaly 252 and library signature: 0.975008974437976 radians
# SAM between anomaly 253 and library signature: 0.9633990998563762 radians
# SAM between anomaly 254 and library signature: 0.9336683322052064 radians
# SAM between anomaly 255 and library signature: 0.9918316962561701 radians
# SAM between anomaly 256 and library signature: 0.9650625227664955 radians
# SAM between anomaly 257 and library signature: 0.9816250560843326 radians
# SAM between anomaly 258 and library signature: 0.9515223138469575 radians
# SAM between anomaly 259 and library signature: 0.9322766967539741 radians
# SAM between anomaly 260 and library signature: 0.8662327769521364 radians
# SAM between anomaly 261 and library signature: 0.9071818850561006 radians
# SAM between anomaly 262 and library signature: 0.8883400978779786 radians
# SAM between anomaly 263 and library signature: 0.918608480054957 radians
# SAM between anomaly 264 and library signature: nan radians
# SAM between anomaly 265 and library signature: nan radians
# SAM between anomaly 266 and library signature: nan radians
# SAM between anomaly 267 and library signature: nan radians
# SAM between anomaly 268 and library signature: nan radians
# SAM between anomaly 269 and library signature: nan radians
# SAM between anomaly 270 and library signature: nan radians
# SAM between anomaly 271 and library signature: 0.9585606325924383 radians
# SAM between anomaly 272 and library signature: 0.9467432893981373 radians
# SAM between anomaly 273 and library signature: 0.9457783583037513 radians
# SAM between anomaly 274 and library signature: 0.9472097570101468 radians
# SAM between anomaly 275 and library signature: 0.9374965574241259 radians
# SAM between anomaly 276 and library signature: 0.9542564400672903 radians
# SAM between anomaly 277 and library signature: 0.9396768973672603 radians
# SAM between anomaly 278 and library signature: 0.9354792835262103 radians
# SAM between anomaly 279 and library signature: 0.921682583207249 radians
# SAM between anomaly 280 and library signature: 0.9080078535070474 radians
# SAM between anomaly 281 and library signature: 0.9484898717152708 radians
# SAM between anomaly 282 and library signature: 0.9498789110552834 radians
# SAM between anomaly 283 and library signature: 0.9758029558639362 radians
# SAM between anomaly 284 and library signature: 0.9575082158561498 radians
# SAM between anomaly 285 and library signature: 0.9474145398993812 radians
# SAM between anomaly 286 and library signature: 0.9498678604662232 radians
# SAM between anomaly 287 and library signature: 0.9520969437184382 radians
# SAM between anomaly 288 and library signature: 0.8684164512710988 radians
# SAM between anomaly 289 and library signature: 0.8222145615681005 radians
# SAM between anomaly 290 and library signature: 0.9063753331845503 radians
# SAM between anomaly 291 and library signature: 0.994969078553608 radians
# SAM between anomaly 292 and library signature: 0.9373627107389264 radians
# SAM between anomaly 293 and library signature: 0.9495667617688865 radians
# SAM between anomaly 294 and library signature: 0.9625156839913058 radians
# SAM between anomaly 295 and library signature: 0.8961072693056682 radians
# SAM between anomaly 296 and library signature: 0.8209081509003762 radians
# SAM between anomaly 297 and library signature: 0.920786312210365 radians
# SAM between anomaly 298 and library signature: 0.9419495600781146 radians
# SAM between anomaly 299 and library signature: 0.9821550641587591 radians
# SAM between anomaly 300 and library signature: 0.9764842943571961 radians
# SAM between anomaly 301 and library signature: 0.9469011445389443 radians
# SAM between anomaly 302 and library signature: 0.8428696640894714 radians
# SAM between anomaly 303 and library signature: 0.9083422148367364 radians
# SAM between anomaly 304 and library signature: 0.8980920786965083 radians
# SAM between anomaly 305 and library signature: 0.8967470466109977 radians
# SAM between anomaly 306 and library signature: 0.8777151952251124 radians
# SAM between anomaly 307 and library signature: 0.9137266143557026 radians
# SAM between anomaly 308 and library signature: 0.9174995129798389 radians
# SAM between anomaly 309 and library signature: 0.914522823022212 radians
# SAM between anomaly 310 and library signature: nan radians
# SAM between anomaly 311 and library signature: nan radians
# SAM between anomaly 312 and library signature: nan radians
# SAM between anomaly 313 and library signature: nan radians
# SAM between anomaly 314 and library signature: nan radians
# SAM between anomaly 315 and library signature: nan radians
# SAM between anomaly 316 and library signature: nan radians
# SAM between anomaly 317 and library signature: nan radians
# SAM between anomaly 318 and library signature: nan radians
# SAM between anomaly 319 and library signature: nan radians
# SAM between anomaly 320 and library signature: 0.9486904185322524 radians
# SAM between anomaly 321 and library signature: 0.9544594784842192 radians
# SAM between anomaly 322 and library signature: 0.948937578386782 radians
# SAM between anomaly 323 and library signature: 0.9225207159744577 radians
# SAM between anomaly 324 and library signature: 0.9255912778182211 radians
# SAM between anomaly 325 and library signature: 0.9163285562072692 radians
# SAM between anomaly 326 and library signature: 0.9306799178809345 radians
# SAM between anomaly 327 and library signature: 0.8920010074157105 radians
# SAM between anomaly 328 and library signature: 0.9310496438392968 radians
# SAM between anomaly 329 and library signature: 0.9527214063049614 radians
# SAM between anomaly 330 and library signature: 0.9729132210954754 radians
# SAM between anomaly 331 and library signature: 0.9793977985853438 radians
# SAM between anomaly 332 and library signature: 0.9738345481557801 radians
# SAM between anomaly 333 and library signature: 0.9795413379524279 radians
# SAM between anomaly 334 and library signature: 0.9401398100538322 radians
# SAM between anomaly 335 and library signature: 0.8749936424427265 radians
# SAM between anomaly 336 and library signature: 0.851114898887214 radians
# SAM between anomaly 337 and library signature: 0.8027744164930084 radians
# SAM between anomaly 338 and library signature: 0.8324312090732098 radians
# SAM between anomaly 339 and library signature: 0.8970317376033722 radians
# SAM between anomaly 340 and library signature: 0.9346313129946908 radians
# SAM between anomaly 341 and library signature: 0.9593746715624731 radians
# SAM between anomaly 342 and library signature: 0.8943119017665053 radians
# SAM between anomaly 343 and library signature: 0.8491471845910846 radians
# SAM between anomaly 344 and library signature: 0.8038642776044868 radians
# SAM between anomaly 345 and library signature: 0.8198173577479072 radians
# SAM between anomaly 346 and library signature: 0.9365359985879178 radians
# SAM between anomaly 347 and library signature: 0.9464875263081111 radians
# SAM between anomaly 348 and library signature: 0.9537807177478597 radians
# SAM between anomaly 349 and library signature: 0.9537739583103597 radians
# SAM between anomaly 350 and library signature: 0.9472373243977827 radians
# SAM between anomaly 351 and library signature: 0.8993632144862038 radians
# SAM between anomaly 352 and library signature: 0.8545847131917261 radians
# SAM between anomaly 353 and library signature: 0.9097415155349928 radians
# SAM between anomaly 354 and library signature: 0.9034092041054628 radians
# SAM between anomaly 355 and library signature: 0.9258971255449269 radians
# SAM between anomaly 356 and library signature: nan radians
# SAM between anomaly 357 and library signature: nan radians
# SAM between anomaly 358 and library signature: nan radians
# SAM between anomaly 359 and library signature: nan radians
# SAM between anomaly 360 and library signature: nan radians
# SAM between anomaly 361 and library signature: nan radians
# SAM between anomaly 362 and library signature: nan radians
# SAM between anomaly 363 and library signature: nan radians
# SAM between anomaly 364 and library signature: nan radians
# SAM between anomaly 365 and library signature: nan radians
# SAM between anomaly 366 and library signature: nan radians
# SAM between anomaly 367 and library signature: nan radians
# SAM between anomaly 368 and library signature: nan radians
# SAM between anomaly 369 and library signature: 0.8886485090507308 radians
# SAM between anomaly 370 and library signature: 0.922711461037761 radians
# SAM between anomaly 371 and library signature: 0.9046183240701504 radians
# SAM between anomaly 372 and library signature: 0.9240548991788793 radians
# SAM between anomaly 373 and library signature: 0.9205385065506503 radians
# SAM between anomaly 374 and library signature: 0.9157193291120966 radians
# SAM between anomaly 375 and library signature: 0.9661635297320886 radians
# SAM between anomaly 376 and library signature: 0.9607408249635564 radians
# SAM between anomaly 377 and library signature: 0.974182011842148 radians
# SAM between anomaly 378 and library signature: 0.9384157293036299 radians
# SAM between anomaly 379 and library signature: 0.8334126917051996 radians
# SAM between anomaly 380 and library signature: 0.7997124066467807 radians
# SAM between anomaly 381 and library signature: 0.7920362472823705 radians
# SAM between anomaly 382 and library signature: 0.825654709755581 radians
# SAM between anomaly 383 and library signature: 0.8497322888795352 radians
# SAM between anomaly 384 and library signature: 0.857400125287241 radians
# SAM between anomaly 385 and library signature: 0.8239829173133083 radians
# SAM between anomaly 386 and library signature: 0.8110307839370056 radians
# SAM between anomaly 387 and library signature: 0.9549490640888286 radians
# SAM between anomaly 388 and library signature: 0.9677651744813192 radians
# SAM between anomaly 389 and library signature: 0.9515213882606847 radians
# SAM between anomaly 390 and library signature: 0.9399000063211032 radians
# SAM between anomaly 391 and library signature: 0.9436277992778852 radians
# SAM between anomaly 392 and library signature: 0.969625840611213 radians
# SAM between anomaly 393 and library signature: 0.9616719958583384 radians
# SAM between anomaly 394 and library signature: 0.8752114892731022 radians
# SAM between anomaly 395 and library signature: 0.9058485012851027 radians
# SAM between anomaly 396 and library signature: nan radians
# SAM between anomaly 397 and library signature: nan radians
# SAM between anomaly 398 and library signature: nan radians
# SAM between anomaly 399 and library signature: nan radians
# SAM between anomaly 400 and library signature: nan radians
# SAM between anomaly 401 and library signature: nan radians
# SAM between anomaly 402 and library signature: nan radians
# SAM between anomaly 403 and library signature: nan radians
# SAM between anomaly 404 and library signature: nan radians
# SAM between anomaly 405 and library signature: nan radians
# SAM between anomaly 406 and library signature: nan radians
# SAM between anomaly 407 and library signature: nan radians
# SAM between anomaly 408 and library signature: nan radians
# SAM between anomaly 409 and library signature: nan radians
# SAM between anomaly 410 and library signature: 0.90914150031863 radians
# SAM between anomaly 411 and library signature: 0.9177460664093465 radians
# SAM between anomaly 412 and library signature: 0.8995511583888677 radians
# SAM between anomaly 413 and library signature: 0.9285606119641974 radians
# SAM between anomaly 414 and library signature: 0.9225008885610251 radians
# SAM between anomaly 415 and library signature: 0.9229429785370822 radians
# SAM between anomaly 416 and library signature: 0.909174804862734 radians
# SAM between anomaly 417 and library signature: 0.9149605195087613 radians
# SAM between anomaly 418 and library signature: 0.950175497111139 radians
# SAM between anomaly 419 and library signature: 0.9349711302704846 radians
# SAM between anomaly 420 and library signature: 0.9455835811960845 radians
# SAM between anomaly 421 and library signature: 0.9782844628623463 radians
# SAM between anomaly 422 and library signature: 0.9873357602528111 radians
# SAM between anomaly 423 and library signature: 0.9475103603526434 radians
# SAM between anomaly 424 and library signature: 0.8857388175125243 radians
# SAM between anomaly 425 and library signature: 0.8384235072155247 radians
# SAM between anomaly 426 and library signature: 0.8053286854581031 radians
# SAM between anomaly 427 and library signature: 0.8698738423590896 radians
# SAM between anomaly 428 and library signature: 0.8507895087149996 radians
# SAM between anomaly 429 and library signature: 0.8009370745156852 radians
# SAM between anomaly 430 and library signature: 0.8403901086966145 radians
# SAM between anomaly 431 and library signature: 0.8146089357550016 radians
# SAM between anomaly 432 and library signature: 0.8088357004815538 radians
# SAM between anomaly 433 and library signature: 0.9691081990227991 radians
# SAM between anomaly 434 and library signature: 0.9709446675193689 radians
# SAM between anomaly 435 and library signature: 0.9676319665309558 radians
# SAM between anomaly 436 and library signature: 0.9835069739544067 radians
# SAM between anomaly 437 and library signature: 0.9192767171973603 radians
# SAM between anomaly 438 and library signature: 0.8802858111741915 radians
# SAM between anomaly 439 and library signature: 0.8734028941610364 radians
# SAM between anomaly 440 and library signature: 0.8955159587972273 radians
# SAM between anomaly 441 and library signature: nan radians
# SAM between anomaly 442 and library signature: nan radians
# SAM between anomaly 443 and library signature: nan radians
# SAM between anomaly 444 and library signature: nan radians
# SAM between anomaly 445 and library signature: nan radians
# SAM between anomaly 446 and library signature: nan radians
# SAM between anomaly 447 and library signature: nan radians
# SAM between anomaly 448 and library signature: nan radians
# SAM between anomaly 449 and library signature: nan radians
# SAM between anomaly 450 and library signature: nan radians
# SAM between anomaly 451 and library signature: nan radians
# SAM between anomaly 452 and library signature: nan radians
# SAM between anomaly 453 and library signature: nan radians
# SAM between anomaly 454 and library signature: nan radians
# SAM between anomaly 455 and library signature: nan radians
# SAM between anomaly 456 and library signature: 0.9155387514700803 radians
# SAM between anomaly 457 and library signature: 0.9081684916180923 radians
# SAM between anomaly 458 and library signature: 0.9182253593390476 radians
# SAM between anomaly 459 and library signature: 0.9660969832544554 radians
# SAM between anomaly 460 and library signature: 0.9548420160354767 radians
# SAM between anomaly 461 and library signature: 0.9603186428124719 radians
# SAM between anomaly 462 and library signature: 1.0028884466642125 radians
# SAM between anomaly 463 and library signature: 0.94231594125504 radians
# SAM between anomaly 464 and library signature: 0.8538887616661713 radians
# SAM between anomaly 465 and library signature: 0.8255994016269073 radians
# SAM between anomaly 466 and library signature: 0.8279858854213469 radians
# SAM between anomaly 467 and library signature: 0.8586747535873811 radians
# SAM between anomaly 468 and library signature: 0.8725893158479705 radians
# SAM between anomaly 469 and library signature: 0.8498133435468226 radians
# SAM between anomaly 470 and library signature: 0.8813530013373759 radians
# SAM between anomaly 471 and library signature: 0.7863674583023451 radians
# SAM between anomaly 472 and library signature: 0.7989901921903979 radians
# SAM between anomaly 473 and library signature: 0.7911391019889799 radians
# SAM between anomaly 474 and library signature: 0.827979206691264 radians
# SAM between anomaly 475 and library signature: 1.003895919669781 radians
# SAM between anomaly 476 and library signature: 0.9738266415055976 radians
# SAM between anomaly 477 and library signature: 0.9527219515365171 radians
# SAM between anomaly 478 and library signature: 0.960789256296387 radians
# SAM between anomaly 479 and library signature: 0.9280897427333855 radians
# SAM between anomaly 480 and library signature: nan radians
# SAM between anomaly 481 and library signature: nan radians
# SAM between anomaly 482 and library signature: nan radians
# SAM between anomaly 483 and library signature: nan radians
# SAM between anomaly 484 and library signature: nan radians
# SAM between anomaly 485 and library signature: nan radians
# SAM between anomaly 486 and library signature: nan radians
# SAM between anomaly 487 and library signature: nan radians
# SAM between anomaly 488 and library signature: nan radians
# SAM between anomaly 489 and library signature: nan radians
# SAM between anomaly 490 and library signature: nan radians
# SAM between anomaly 491 and library signature: nan radians
# SAM between anomaly 492 and library signature: nan radians
# SAM between anomaly 493 and library signature: nan radians
# SAM between anomaly 494 and library signature: nan radians
# SAM between anomaly 495 and library signature: nan radians
# SAM between anomaly 496 and library signature: nan radians
# SAM between anomaly 497 and library signature: nan radians
# SAM between anomaly 498 and library signature: nan radians
# SAM between anomaly 499 and library signature: nan radians
# SAM between anomaly 500 and library signature: nan radians
# SAM between anomaly 501 and library signature: nan radians
# SAM between anomaly 502 and library signature: nan radians
# SAM between anomaly 503 and library signature: 0.913341796107898 radians
# SAM between anomaly 504 and library signature: 0.9205912538985662 radians
# SAM between anomaly 505 and library signature: 0.9189000754205024 radians
# SAM between anomaly 506 and library signature: 0.92741594972662 radians
# SAM between anomaly 507 and library signature: 0.9405411849943959 radians
# SAM between anomaly 508 and library signature: 0.9730978121342179 radians
# SAM between anomaly 509 and library signature: 0.98602456911696 radians
# SAM between anomaly 510 and library signature: 0.9674479754457472 radians
# SAM between anomaly 511 and library signature: 0.9001157502306537 radians
# SAM between anomaly 512 and library signature: 0.8087447877949969 radians
# SAM between anomaly 513 and library signature: 0.8408651590672422 radians
# SAM between anomaly 514 and library signature: 0.8445333908297177 radians
# SAM between anomaly 515 and library signature: 0.8702509536611208 radians
# SAM between anomaly 516 and library signature: 0.8999019636123355 radians
# SAM between anomaly 517 and library signature: 0.8596165630613396 radians
# SAM between anomaly 518 and library signature: 0.847262945637802 radians
# SAM between anomaly 519 and library signature: 0.8473759020064362 radians
# SAM between anomaly 520 and library signature: 0.8843936236072898 radians
# SAM between anomaly 521 and library signature: 0.8453153718912458 radians
# SAM between anomaly 522 and library signature: 0.791350650996549 radians
# SAM between anomaly 523 and library signature: 0.7825592519601077 radians
# SAM between anomaly 524 and library signature: 0.8619606435622912 radians
# SAM between anomaly 525 and library signature: 0.9614971036009272 radians
# SAM between anomaly 526 and library signature: 1.0200777279230533 radians
# SAM between anomaly 527 and library signature: 0.9302620261101742 radians
# SAM between anomaly 528 and library signature: nan radians
# SAM between anomaly 529 and library signature: nan radians
# SAM between anomaly 530 and library signature: nan radians
# SAM between anomaly 531 and library signature: nan radians
# SAM between anomaly 532 and library signature: nan radians
# SAM between anomaly 533 and library signature: nan radians
# SAM between anomaly 534 and library signature: nan radians
# SAM between anomaly 535 and library signature: nan radians
# SAM between anomaly 536 and library signature: nan radians
# SAM between anomaly 537 and library signature: nan radians
# SAM between anomaly 538 and library signature: nan radians
# SAM between anomaly 539 and library signature: nan radians
# SAM between anomaly 540 and library signature: nan radians
# SAM between anomaly 541 and library signature: nan radians
# SAM between anomaly 542 and library signature: nan radians
# SAM between anomaly 543 and library signature: nan radians
# SAM between anomaly 544 and library signature: 0.918077667038432 radians
# SAM between anomaly 545 and library signature: 0.9263946093841879 radians
# SAM between anomaly 546 and library signature: 0.922580298368428 radians
# SAM between anomaly 547 and library signature: 0.9118730253902738 radians
# SAM between anomaly 548 and library signature: 0.9260827326725772 radians
# SAM between anomaly 549 and library signature: 0.9390237411005382 radians
# SAM between anomaly 550 and library signature: 0.9570420861461435 radians
# SAM between anomaly 551 and library signature: 0.961591064050642 radians
# SAM between anomaly 552 and library signature: 0.9431871234580866 radians
# SAM between anomaly 553 and library signature: 0.9497373969190714 radians
# SAM between anomaly 554 and library signature: 0.8948914138903183 radians
# SAM between anomaly 555 and library signature: 0.8545583210387574 radians
# SAM between anomaly 556 and library signature: 0.8200486560907851 radians
# SAM between anomaly 557 and library signature: 0.9431748819956781 radians
# SAM between anomaly 558 and library signature: 0.932999881479704 radians
# SAM between anomaly 559 and library signature: 0.8819493531310918 radians
# SAM between anomaly 560 and library signature: 0.8651570887931729 radians
# SAM between anomaly 561 and library signature: 0.7979932273435026 radians
# SAM between anomaly 562 and library signature: 0.812324335651354 radians
# SAM between anomaly 563 and library signature: 1.028711303110846 radians
# SAM between anomaly 564 and library signature: 1.0004481459984595 radians
# SAM between anomaly 565 and library signature: 0.9717525759618975 radians
# SAM between anomaly 566 and library signature: 0.9455653669536843 radians
# SAM between anomaly 567 and library signature: 0.9613293047633453 radians
# SAM between anomaly 568 and library signature: 0.917475338193666 radians
# SAM between anomaly 569 and library signature: 0.8936195525847513 radians
# SAM between anomaly 570 and library signature: 0.9608275570544594 radians
# SAM between anomaly 571 and library signature: 0.9148929032192308 radians
# SAM between anomaly 572 and library signature: nan radians
# SAM between anomaly 573 and library signature: nan radians
# SAM between anomaly 574 and library signature: nan radians
# SAM between anomaly 575 and library signature: nan radians
# SAM between anomaly 576 and library signature: nan radians
# SAM between anomaly 577 and library signature: nan radians
# SAM between anomaly 578 and library signature: nan radians
# SAM between anomaly 579 and library signature: nan radians
# SAM between anomaly 580 and library signature: nan radians
# SAM between anomaly 581 and library signature: nan radians
# SAM between anomaly 582 and library signature: nan radians
# SAM between anomaly 583 and library signature: nan radians
# SAM between anomaly 584 and library signature: nan radians
# SAM between anomaly 585 and library signature: nan radians
# SAM between anomaly 586 and library signature: nan radians
# SAM between anomaly 587 and library signature: nan radians
# SAM between anomaly 588 and library signature: nan radians
# SAM between anomaly 589 and library signature: nan radians
# SAM between anomaly 590 and library signature: nan radians
# SAM between anomaly 591 and library signature: nan radians
# SAM between anomaly 592 and library signature: 0.9225309278827116 radians
# SAM between anomaly 593 and library signature: 0.9195052815088532 radians
# SAM between anomaly 594 and library signature: 0.9187042171719205 radians
# SAM between anomaly 595 and library signature: 0.914625140039222 radians
# SAM between anomaly 596 and library signature: 0.9183129147090106 radians
# SAM between anomaly 597 and library signature: 0.911356094709461 radians
# SAM between anomaly 598 and library signature: 0.9345691697432041 radians
# SAM between anomaly 599 and library signature: 0.966823398485561 radians
# SAM between anomaly 600 and library signature: 0.9452949202651885 radians
# SAM between anomaly 601 and library signature: 0.8178630706347274 radians
# SAM between anomaly 602 and library signature: 0.8601062562059142 radians
# SAM between anomaly 603 and library signature: 0.9620004993425245 radians
# SAM between anomaly 604 and library signature: 0.9352443855249382 radians
# SAM between anomaly 605 and library signature: 0.9428700142928557 radians
# SAM between anomaly 606 and library signature: 0.9329592793497251 radians
# SAM between anomaly 607 and library signature: 0.8614495690806646 radians
# SAM between anomaly 608 and library signature: 0.8477911672721473 radians
# SAM between anomaly 609 and library signature: 0.8626604713406992 radians
# SAM between anomaly 610 and library signature: 0.8102413234064338 radians
# SAM between anomaly 611 and library signature: 0.8033019496605602 radians
# SAM between anomaly 612 and library signature: 0.8345565460774828 radians
# SAM between anomaly 613 and library signature: 0.7930252167816846 radians
# SAM between anomaly 614 and library signature: 0.9006309445806214 radians
# SAM between anomaly 615 and library signature: 0.9794259835475528 radians
# SAM between anomaly 616 and library signature: 0.9460140854115402 radians
# SAM between anomaly 617 and library signature: 0.9255554398594825 radians
# SAM between anomaly 618 and library signature: 0.9262272187172939 radians
# SAM between anomaly 619 and library signature: 0.918114484105488 radians
# SAM between anomaly 620 and library signature: 0.9121846328119296 radians
# SAM between anomaly 621 and library signature: 0.8671160080350419 radians
# SAM between anomaly 622 and library signature: 0.9121647441675953 radians
# SAM between anomaly 623 and library signature: nan radians
# SAM between anomaly 624 and library signature: nan radians
# SAM between anomaly 625 and library signature: nan radians
# SAM between anomaly 626 and library signature: nan radians
# SAM between anomaly 627 and library signature: nan radians
# SAM between anomaly 628 and library signature: nan radians
# SAM between anomaly 629 and library signature: nan radians
# SAM between anomaly 630 and library signature: nan radians
# SAM between anomaly 631 and library signature: nan radians
# SAM between anomaly 632 and library signature: nan radians
# SAM between anomaly 633 and library signature: nan radians
# SAM between anomaly 634 and library signature: nan radians
# SAM between anomaly 635 and library signature: nan radians
# SAM between anomaly 636 and library signature: nan radians
# SAM between anomaly 637 and library signature: nan radians
# SAM between anomaly 638 and library signature: nan radians
# SAM between anomaly 639 and library signature: nan radians
# SAM between anomaly 640 and library signature: nan radians
# SAM between anomaly 641 and library signature: nan radians
# SAM between anomaly 642 and library signature: nan radians
# SAM between anomaly 643 and library signature: 0.9207051995295353 radians
# SAM between anomaly 644 and library signature: 0.9207559111298753 radians
# SAM between anomaly 645 and library signature: 0.9128694587751487 radians
# SAM between anomaly 646 and library signature: 0.9166336529345215 radians
# SAM between anomaly 647 and library signature: 0.9128278272554736 radians
# SAM between anomaly 648 and library signature: 0.9449481818226335 radians
# SAM between anomaly 649 and library signature: 0.8838220582693512 radians
# SAM between anomaly 650 and library signature: 0.9814304206612889 radians
# SAM between anomaly 651 and library signature: 0.9821997788046514 radians
# SAM between anomaly 652 and library signature: 0.958830423067863 radians
# SAM between anomaly 653 and library signature: 0.9171181758932864 radians
# SAM between anomaly 654 and library signature: 0.9807251070813362 radians
# SAM between anomaly 655 and library signature: 0.8136392992914158 radians
# SAM between anomaly 656 and library signature: 0.7896146750279679 radians
# SAM between anomaly 657 and library signature: 0.8240221219060879 radians
# SAM between anomaly 658 and library signature: 0.942442783926765 radians
# SAM between anomaly 659 and library signature: 0.9539154114801912 radians
# SAM between anomaly 660 and library signature: 0.9093595260856648 radians
# SAM between anomaly 661 and library signature: 0.8747495118262287 radians
# SAM between anomaly 662 and library signature: 0.9402281211649951 radians
# SAM between anomaly 663 and library signature: 0.8894426784898437 radians
# SAM between anomaly 664 and library signature: 0.8833130327878911 radians
# SAM between anomaly 665 and library signature: 0.8607438375025265 radians
# SAM between anomaly 666 and library signature: nan radians
# SAM between anomaly 667 and library signature: nan radians
# SAM between anomaly 668 and library signature: nan radians
# SAM between anomaly 669 and library signature: nan radians
# SAM between anomaly 670 and library signature: nan radians
# SAM between anomaly 671 and library signature: nan radians
# SAM between anomaly 672 and library signature: nan radians
# SAM between anomaly 673 and library signature: nan radians
# SAM between anomaly 674 and library signature: nan radians
# SAM between anomaly 675 and library signature: nan radians
# SAM between anomaly 676 and library signature: nan radians
# SAM between anomaly 677 and library signature: nan radians
# SAM between anomaly 678 and library signature: nan radians
# SAM between anomaly 679 and library signature: nan radians
# SAM between anomaly 680 and library signature: nan radians
# SAM between anomaly 681 and library signature: nan radians
# SAM between anomaly 682 and library signature: nan radians
# SAM between anomaly 683 and library signature: nan radians
# SAM between anomaly 684 and library signature: 0.9132190557869742 radians
# SAM between anomaly 685 and library signature: 0.9084276823067179 radians
# SAM between anomaly 686 and library signature: 0.9176144327052335 radians
# SAM between anomaly 687 and library signature: 0.9190424288404022 radians
# SAM between anomaly 688 and library signature: 0.9052178817781104 radians
# SAM between anomaly 689 and library signature: 0.9144179677642096 radians
# SAM between anomaly 690 and library signature: 0.93389688876109 radians
# SAM between anomaly 691 and library signature: 0.9286549989725256 radians
# ...
# SAM between anomaly 7560 and library signature: 0.9216548537243473 radians
# SAM between anomaly 7561 and library signature: 0.8984187121074381 radians
# SAM between anomaly 7562 and library signature: 0.929329548015701 radians
# SAM between anomaly 7563 and library signature: 0.9017555376230907 radians
# SAM between anomaly 7564 and library signature: 0.9063778261139477 radians
# SAM between anomaly 7565 and library signature: 1.1530671573784836 radians
# SAM between anomaly 7566 and library signature: 1.1516482144900917 radians
# SAM between anomaly 7567 and library signature: 1.152152392288334 radians
# SAM between anomaly 7568 and library signature: 1.1528769703326214 radians
# SAM between anomaly 7569 and library signature: 1.1525954082478371 radians
# SAM between anomaly 7570 and library signature: 1.1515727957148758 radians
# SAM between anomaly 7571 and library signature: 1.1507730019690376 radians
# SAM between anomaly 7572 and library signature: 1.1491211958056462 radians
# SAM between anomaly 7573 and library signature: 1.1477362115406953 radians
# SAM between anomaly 7574 and library signature: 1.1473645616539883 radians
# SAM between anomaly 7575 and library signature: 1.1492675604675076 radians
# SAM between anomaly 7576 and library signature: 0.8878185770791233 radians
# SAM between anomaly 7577 and library signature: 0.8271619936764646 radians
# SAM between anomaly 7578 and library signature: 0.9181391621508744 radians
# SAM between anomaly 7579 and library signature: 0.8847114392431681 radians
# SAM between anomaly 7580 and library signature: 0.9135396589731716 radians
# SAM between anomaly 7581 and library signature: 0.901725389805341 radians
# SAM between anomaly 7582 and library signature: 0.918194369185008 radians
# SAM between anomaly 7583 and library signature: nan radians
# SAM between anomaly 7584 and library signature: nan radians
# SAM between anomaly 7585 and library signature: nan radians
# SAM between anomaly 7586 and library signature: nan radians
# SAM between anomaly 7587 and library signature: nan radians
# SAM between anomaly 7588 and library signature: nan radians
# SAM between anomaly 7589 and library signature: nan radians
# SAM between anomaly 7590 and library signature: nan radians
# SAM between anomaly 7591 and library signature: nan radians
# SAM between anomaly 7592 and library signature: nan radians
# SAM between anomaly 7593 and library signature: nan radians
# SAM between anomaly 7594 and library signature: nan radians
# SAM between anomaly 7595 and library signature: nan radians
# SAM between anomaly 7596 and library signature: nan radians
# SAM between anomaly 7597 and library signature: nan radians
# SAM between anomaly 7598 and library signature: nan radians
# SAM between anomaly 7599 and library signature: nan radians
# SAM between anomaly 7600 and library signature: nan radians
# SAM between anomaly 7601 and library signature: nan radians
# SAM between anomaly 7602 and library signature: 0.8590467593573441 radians
# SAM between anomaly 7603 and library signature: 0.8674323981025988 radians
# SAM between anomaly 7604 and library signature: 1.0412264080698597 radians
# SAM between anomaly 7605 and library signature: 1.1527707456805558 radians
# SAM between anomaly 7606 and library signature: 1.1534399914235407 radians
# SAM between anomaly 7607 and library signature: 1.1522818657957572 radians
# SAM between anomaly 7608 and library signature: 1.1521442418398697 radians
# SAM between anomaly 7609 and library signature: 1.1527688700993368 radians
# SAM between anomaly 7610 and library signature: 1.1527843516782657 radians
# SAM between anomaly 7611 and library signature: 1.151567191403051 radians
# SAM between anomaly 7612 and library signature: 1.1499734934489663 radians
# SAM between anomaly 7613 and library signature: 1.1486193148894486 radians
# SAM between anomaly 7614 and library signature: 1.14676484751322 radians
# SAM between anomaly 7615 and library signature: 1.1456514570951666 radians
# SAM between anomaly 7616 and library signature: 1.1452447358853741 radians
# SAM between anomaly 7617 and library signature: 1.1463328338914258 radians
# SAM between anomaly 7618 and library signature: 0.9390045049844223 radians
# SAM between anomaly 7619 and library signature: 0.8448535661722624 radians
# SAM between anomaly 7620 and library signature: 0.8588664421985535 radians
# SAM between anomaly 7621 and library signature: 0.8874081159203492 radians
# SAM between anomaly 7622 and library signature: 0.9241711638150749 radians
# SAM between anomaly 7623 and library signature: 0.9017799486720672 radians
# SAM between anomaly 7624 and library signature: 0.8935536024270413 radians
# SAM between anomaly 7625 and library signature: 0.9064068057690398 radians
# SAM between anomaly 7626 and library signature: 0.9242898853838151 radians
# SAM between anomaly 7627 and library signature: nan radians
# SAM between anomaly 7628 and library signature: nan radians
# SAM between anomaly 7629 and library signature: nan radians
# SAM between anomaly 7630 and library signature: nan radians
# SAM between anomaly 7631 and library signature: nan radians
# SAM between anomaly 7632 and library signature: nan radians
# SAM between anomaly 7633 and library signature: nan radians
# SAM between anomaly 7634 and library signature: nan radians
# SAM between anomaly 7635 and library signature: nan radians
# SAM between anomaly 7636 and library signature: nan radians
# SAM between anomaly 7637 and library signature: nan radians
# SAM between anomaly 7638 and library signature: nan radians
# SAM between anomaly 7639 and library signature: nan radians
# SAM between anomaly 7640 and library signature: nan radians
# SAM between anomaly 7641 and library signature: nan radians
# SAM between anomaly 7642 and library signature: nan radians
# SAM between anomaly 7643 and library signature: nan radians
# SAM between anomaly 7644 and library signature: nan radians
# SAM between anomaly 7645 and library signature: nan radians
# SAM between anomaly 7646 and library signature: nan radians
# SAM between anomaly 7647 and library signature: nan radians
# SAM between anomaly 7648 and library signature: nan radians
# SAM between anomaly 7649 and library signature: nan radians
# SAM between anomaly 7650 and library signature: 1.1539471754454789 radians
# SAM between anomaly 7651 and library signature: 1.1534948433505414 radians
# SAM between anomaly 7652 and library signature: 1.1533426168500773 radians
# SAM between anomaly 7653 and library signature: 1.152799886604234 radians
# SAM between anomaly 7654 and library signature: 1.1530800349015593 radians
# SAM between anomaly 7655 and library signature: 1.1536498462656974 radians
# SAM between anomaly 7656 and library signature: 1.1527434138434616 radians
# SAM between anomaly 7657 and library signature: 1.149244797441373 radians
# SAM between anomaly 7658 and library signature: 1.14800408735912 radians
# SAM between anomaly 7659 and library signature: 1.146942351181448 radians
# SAM between anomaly 7660 and library signature: 1.1465602224478624 radians
# SAM between anomaly 7661 and library signature: 1.1464949888244258 radians
# SAM between anomaly 7662 and library signature: 1.1485574257834068 radians
# SAM between anomaly 7663 and library signature: 1.1492881320626167 radians
# SAM between anomaly 7664 and library signature: 0.9266155906562739 radians
# SAM between anomaly 7665 and library signature: 0.9224324535853375 radians
# SAM between anomaly 7666 and library signature: 0.8896096000817728 radians
# SAM between anomaly 7667 and library signature: 0.891406802652272 radians
# SAM between anomaly 7668 and library signature: 0.8953298528079213 radians
# SAM between anomaly 7669 and library signature: 0.9071664361529973 radians
# SAM between anomaly 7670 and library signature: nan radians
# SAM between anomaly 7671 and library signature: nan radians
# SAM between anomaly 7672 and library signature: nan radians
# SAM between anomaly 7673 and library signature: nan radians
# SAM between anomaly 7674 and library signature: nan radians
# SAM between anomaly 7675 and library signature: nan radians
# SAM between anomaly 7676 and library signature: nan radians
# SAM between anomaly 7677 and library signature: nan radians
# SAM between anomaly 7678 and library signature: nan radians
# SAM between anomaly 7679 and library signature: nan radians
# SAM between anomaly 7680 and library signature: nan radians
# SAM between anomaly 7681 and library signature: nan radians
# SAM between anomaly 7682 and library signature: nan radians
# SAM between anomaly 7683 and library signature: nan radians
# SAM between anomaly 7684 and library signature: nan radians
# SAM between anomaly 7685 and library signature: nan radians
# SAM between anomaly 7686 and library signature: nan radians
# SAM between anomaly 7687 and library signature: nan radians
# SAM between anomaly 7688 and library signature: nan radians
# SAM between anomaly 7689 and library signature: nan radians
# SAM between anomaly 7690 and library signature: nan radians
# SAM between anomaly 7691 and library signature: nan radians
# SAM between anomaly 7692 and library signature: nan radians
# SAM between anomaly 7693 and library signature: nan radians
# SAM between anomaly 7694 and library signature: nan radians
# SAM between anomaly 7695 and library signature: nan radians
# SAM between anomaly 7696 and library signature: nan radians
# SAM between anomaly 7697 and library signature: nan radians
# SAM between anomaly 7698 and library signature: 1.154608012407559 radians
# SAM between anomaly 7699 and library signature: 1.1539732626739894 radians
# SAM between anomaly 7700 and library signature: 1.1532363512484423 radians
# SAM between anomaly 7701 and library signature: 1.1506637182298616 radians
# SAM between anomaly 7702 and library signature: 1.1493286710254147 radians
# SAM between anomaly 7703 and library signature: 1.1473100630526964 radians
# SAM between anomaly 7704 and library signature: 1.148565013067225 radians
# SAM between anomaly 7705 and library signature: 1.1504776980278721 radians
# SAM between anomaly 7706 and library signature: 1.1521595160625155 radians
# SAM between anomaly 7707 and library signature: 1.0427626551890152 radians
# SAM between anomaly 7708 and library signature: 0.8940161724120455 radians
# SAM between anomaly 7709 and library signature: 0.8715960547055419 radians
# SAM between anomaly 7710 and library signature: 0.8551654692747623 radians
# SAM between anomaly 7711 and library signature: 0.8928132502532069 radians
# SAM between anomaly 7712 and library signature: 0.8823292454426099 radians
# SAM between anomaly 7713 and library signature: nan radians
# SAM between anomaly 7714 and library signature: nan radians
# SAM between anomaly 7715 and library signature: nan radians
# SAM between anomaly 7716 and library signature: nan radians
# SAM between anomaly 7717 and library signature: nan radians
# SAM between anomaly 7718 and library signature: nan radians
# SAM between anomaly 7719 and library signature: nan radians
# SAM between anomaly 7720 and library signature: nan radians
# SAM between anomaly 7721 and library signature: nan radians
# SAM between anomaly 7722 and library signature: nan radians
# SAM between anomaly 7723 and library signature: nan radians
# SAM between anomaly 7724 and library signature: nan radians
# SAM between anomaly 7725 and library signature: nan radians
# SAM between anomaly 7726 and library signature: nan radians
# SAM between anomaly 7727 and library signature: nan radians
# SAM between anomaly 7728 and library signature: nan radians
# SAM between anomaly 7729 and library signature: nan radians
# SAM between anomaly 7730 and library signature: nan radians
# SAM between anomaly 7731 and library signature: nan radians
# SAM between anomaly 7732 and library signature: nan radians
# SAM between anomaly 7733 and library signature: nan radians
# SAM between anomaly 7734 and library signature: nan radians
# SAM between anomaly 7735 and library signature: nan radians
# SAM between anomaly 7736 and library signature: nan radians
# SAM between anomaly 7737 and library signature: nan radians
# SAM between anomaly 7738 and library signature: nan radians
# SAM between anomaly 7739 and library signature: nan radians
# SAM between anomaly 7740 and library signature: nan radians
# SAM between anomaly 7741 and library signature: nan radians
# SAM between anomaly 7742 and library signature: nan radians
# SAM between anomaly 7743 and library signature: nan radians
# SAM between anomaly 7744 and library signature: nan radians
# SAM between anomaly 7745 and library signature: 1.148064072029758 radians
# SAM between anomaly 7746 and library signature: 1.1476999810603605 radians
# SAM between anomaly 7747 and library signature: 1.1466670314103868 radians
# SAM between anomaly 7748 and library signature: 1.1480540683344287 radians
# SAM between anomaly 7749 and library signature: 1.154184761009423 radians
# SAM between anomaly 7750 and library signature: 1.1544074701536224 radians
# SAM between anomaly 7751 and library signature: 0.991471792828618 radians
# SAM between anomaly 7752 and library signature: 0.8616721367399607 radians
# SAM between anomaly 7753 and library signature: 0.9026590534490786 radians
# SAM between anomaly 7754 and library signature: nan radians
# SAM between anomaly 7755 and library signature: nan radians
# SAM between anomaly 7756 and library signature: nan radians
# SAM between anomaly 7757 and library signature: nan radians
# SAM between anomaly 7758 and library signature: nan radians
# SAM between anomaly 7759 and library signature: nan radians
# SAM between anomaly 7760 and library signature: nan radians
# SAM between anomaly 7761 and library signature: nan radians
# SAM between anomaly 7762 and library signature: nan radians
# SAM between anomaly 7763 and library signature: nan radians
# SAM between anomaly 7764 and library signature: nan radians
# SAM between anomaly 7765 and library signature: nan radians
# SAM between anomaly 7766 and library signature: nan radians
# SAM between anomaly 7767 and library signature: nan radians
# SAM between anomaly 7768 and library signature: nan radians
# SAM between anomaly 7769 and library signature: nan radians
# SAM between anomaly 7770 and library signature: nan radians
# SAM between anomaly 7771 and library signature: nan radians
# SAM between anomaly 7772 and library signature: nan radians
# SAM between anomaly 7773 and library signature: nan radians
# SAM between anomaly 7774 and library signature: nan radians
# SAM between anomaly 7775 and library signature: nan radians
# SAM between anomaly 7776 and library signature: nan radians
# SAM between anomaly 7777 and library signature: nan radians
# SAM between anomaly 7778 and library signature: nan radians
# SAM between anomaly 7779 and library signature: nan radians
# SAM between anomaly 7780 and library signature: nan radians
# SAM between anomaly 7781 and library signature: nan radians
# SAM between anomaly 7782 and library signature: nan radians
# SAM between anomaly 7783 and library signature: nan radians
# SAM between anomaly 7784 and library signature: nan radians
# SAM between anomaly 7785 and library signature: nan radians
# SAM between anomaly 7786 and library signature: nan radians
# SAM between anomaly 7787 and library signature: nan radians
# SAM between anomaly 7788 and library signature: nan radians
# SAM between anomaly 7789 and library signature: nan radians
# SAM between anomaly 7790 and library signature: 1.1503930673098937 radians
# SAM between anomaly 7791 and library signature: 1.1536981709268985 radians
# SAM between anomaly 7792 and library signature: 1.1158954308364664 radians
# SAM between anomaly 7793 and library signature: 0.8508110756690492 radians
# SAM between anomaly 7794 and library signature: nan radians
# SAM between anomaly 7795 and library signature: nan radians
# SAM between anomaly 7796 and library signature: nan radians
# SAM between anomaly 7797 and library signature: nan radians
# SAM between anomaly 7798 and library signature: nan radians
# SAM between anomaly 7799 and library signature: nan radians
# SAM between anomaly 7800 and library signature: nan radians
# SAM between anomaly 7801 and library signature: nan radians

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Define a threshold for SAM (in radians) for similarity
sam_threshold = 0.8  # Adjust this value as needed

# Assume `sams` is an array of SAM values calculated previously
# Identify anomalies with SAM values below the threshold
close_matches = [
    (idx, sam) for idx, sam in enumerate(sams) if sam < sam_threshold
]

# Output anomalies with close matches
if close_matches:
    # Automatically collect indices of close matches
    close_match_indices = [idx for idx, sam in close_matches]
    for idx, sam in close_matches:
        print(f"Anomaly {idx + 1} has a close match to the library signature with SAM: {sam:.2f} radians")
else:
    print("No anomalies closely match the spectral library signature.")
# Out:
# Anomaly 380 has a close match to the library signature with SAM: 0.80 radians
# Anomaly 381 has a close match to the library signature with SAM: 0.79 radians
# Anomaly 471 has a close match to the library signature with SAM: 0.79 radians
# Anomaly 472 has a close match to the library signature with SAM: 0.80 radians
# Anomaly 473 has a close match to the library signature with SAM: 0.79 radians
# Anomaly 522 has a close match to the library signature with SAM: 0.79 radians
# Anomaly 523 has a close match to the library signature with SAM: 0.78 radians
# Anomaly 561 has a close match to the library signature with SAM: 0.80 radians
# Anomaly 613 has a close match to the library signature with SAM: 0.79 radians
# Anomaly 656 has a close match to the library signature with SAM: 0.79 radians
# Anomaly 696 has a close match to the library signature with SAM: 0.80 radians
# Anomaly 1982 has a close match to the library signature with SAM: 0.78 radians
# Anomaly 3902 has a close match to the library signature with SAM: 0.79 radians

# %%
def visualize_anomalies_on_image(image, patch_size, anomaly_indices, image_shape):
    """
    Visualizes the detected anomalies on the original image.

    Parameters:
    - image: The original hyperspectral image (single band or RGB composite).
    - patch_size: Size of each patch (e.g., 16).
    - anomaly_indices: List of indices of detected anomalies (e.g., [983, 3261, 3439, 9026]).
    - image_shape: Shape of the original hyperspectral image (height, width).
    """
    h, w = image_shape[:2]
    
    # Convert anomaly indices to 2D patch locations
    anomaly_positions = []
    for patch_idx in anomaly_indices:
        # Convert the linear index to 2D coordinates
        row = (patch_idx // (w // patch_size)) * patch_size
        col = (patch_idx % (w // patch_size)) * patch_size
        center_x = col + patch_size // 2
        center_y = row + patch_size // 2
        anomaly_positions.append((center_x, center_y))

    plt.figure(figsize=(12, 6))

    # Display the original image (use a representative band, e.g., band 30)
    plt.imshow(image[:, :, 30], cmap='gray')  # Adjust band as needed
    plt.title("Original Image with Detected Anomalies")

    # Plot red circles at the anomaly locations
    ax = plt.gca()
    for (x, y) in anomaly_positions:
        circle = patches.Circle((x, y), radius=patch_size // 3, edgecolor='red', facecolor='none', linewidth=2)
        ax.add_patch(circle)

    plt.show()

# Example usage:
image_shape = sample_image.shape  # Shape of your original hyperspectral image
patch_size = 16  # Adjust based on your patch size
anomaly_indices = close_match_indices  # Use the indices of close matches

# Visualize the anomalies with red circles
visualize_anomalies_on_image(sample_image, patch_size, anomaly_indices, image_shape)
import re

def read_hdr_file(hdr_file_path):
    """
    Reads the HDR file and extracts the required parameters.
    
    Parameters:
    - hdr_file_path: Path to the HDR file.
    
    Returns:
    - A dictionary with extracted parameters (upper_left_easting, upper_left_northing, pixel_size, image_samples, image_lines).
    """
    hdr_params = {}
    
    # Open the HDR file and read its content
    with open(hdr_file_path, 'r') as hdr_file:
        hdr_content = hdr_file.read()

    # Regular expressions to match the parameters
    easting_match = re.search(r'upper left corner \(1,1\) \(Easting\) =\s*(\d+\.\d+)', hdr_content)
    northing_match = re.search(r'upper left corner \(1,1\) \(Northing\) =\s*(\d+\.\d+)', hdr_content)
    pixel_size_match = re.search(r'pixel size\s*=\s*(\d+\.\d+)', hdr_content)
    samples_match = re.search(r'samples\s*=\s*(\d+)', hdr_content)
    lines_match = re.search(r'lines\s*=\s*(\d+)', hdr_content)

    # Extract values from the regex matches and store them in the dictionary
    if easting_match:
        hdr_params['upper_left_easting'] = float(easting_match.group(1))
    if northing_match:
        hdr_params['upper_left_northing'] = float(northing_match.group(1))
    if pixel_size_match:
        hdr_params['pixel_size'] = float(pixel_size_match.group(1))
    if samples_match:
        hdr_params['image_samples'] = int(samples_match.group(1))
    if lines_match:
        hdr_params['image_lines'] = int(lines_match.group(1))
    
    return hdr_params

def calculate_geographical_coordinates(anomaly_indices, hdr_params, image_shape):
    """
    Calculate the geographical coordinates (Easting and Northing) for given anomaly indices using extracted HDR parameters.
    
    Parameters:
    - anomaly_indices: List of indices of detected anomalies.
    - hdr_params: Dictionary with extracted HDR parameters.
    - image_shape: Shape of the original hyperspectral image (height, width).
    
    Returns:
    - List of tuples containing anomaly index, easting, and northing.
    """
    # Extract parameters from the hdr_params dictionary
    pixel_size = hdr_params['pixel_size']
    upper_left_easting = hdr_params['upper_left_easting']
    upper_left_northing = hdr_params['upper_left_northing']
    image_samples = hdr_params['image_samples']
    image_lines = hdr_params['image_lines']
    
    h, w = image_shape[:2]
    geographical_locations = []

    for idx in anomaly_indices:
        # Calculate the row and column from the anomaly index
        row = idx // w  # Calculate row directly from index
        col = idx % w  # Calculate column directly from index
        
        # Calculate the Easting and Northing coordinates
        easting = upper_left_easting + (col * pixel_size)
        northing = upper_left_northing - (row * pixel_size)  # Subtract because Northing decreases as you go down
        
        geographical_locations.append((idx, easting, northing))

    return geographical_locations

# Example usage:
hdr_file_path = "C:\\21261A3234\\Projects\\mini\\Datasets\\AVIRIS_2021 flight lines\\f100506t01p00r08\\f100506t01p00r08rdn_b\\f100506t01p00r08rdn_b_sc01_ort_img.hdr"
hdr_params = read_hdr_file(hdr_file_path)

# Assuming 'sample_image' is your loaded hyperspectral image
image_shape = sample_image.shape  # Shape of your original hyperspectral image

# Calculate geographical coordinates for the anomalies based on close matches
geographical_locations = calculate_geographical_coordinates(close_match_indices, hdr_params, image_shape)

# Print the geographical locations of anomalies
for anomaly_idx, easting, northing in geographical_locations:
    print(f"Anomaly {anomaly_idx + 1}: Easting = {easting:.2f}, Northing = {northing:.2f}")
# Out:
# Anomaly 380: Easting = 492430.07, Northing = 3291796.70
# Anomaly 381: Easting = 492446.87, Northing = 3291796.70
# Anomaly 471: Easting = 493958.87, Northing = 3291796.70
# Anomaly 472: Easting = 493975.67, Northing = 3291796.70
# Anomaly 473: Easting = 493992.47, Northing = 3291796.70
# Anomaly 522: Easting = 494815.67, Northing = 3291796.70
# Anomaly 523: Easting = 494832.47, Northing = 3291796.70
# Anomaly 561: Easting = 495470.87, Northing = 3291796.70
# Anomaly 613: Easting = 496344.47, Northing = 3291796.70
# Anomaly 656: Easting = 497066.87, Northing = 3291796.70
# Anomaly 696: Easting = 497738.87, Northing = 3291796.70
# Anomaly 1982: Easting = 501266.87, Northing = 3291779.90
# Anomaly 3902: Easting = 497369.27, Northing = 3291746.30
